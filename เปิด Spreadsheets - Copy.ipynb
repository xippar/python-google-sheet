# %%
# !pip install ezsheets
# Out:
# ...
#   Using cached EZSheets-2020.10.10.tar.gz (19 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#     Preparing wheel metadata: started
#     Preparing wheel metadata: finished with status 'done'
# ...
#   Using cached uritemplate-3.0.1-py2.py3-none-any.whl (15 kB)
# ...
#   Using cached requests_oauthlib-1.3.0-py2.py3-none-any.whl (23 kB)
# ...
#   Using cached pyasn1_modules-0.2.8-py2.py3-none-any.whl (155 kB)
# ...
#   Using cached oauthlib-3.1.0-py2.py3-none-any.whl (147 kB)
# ...
#   Using cached pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
# ...
#   Created wheel for ezsheets: filename=EZSheets-2020.10.10-py3-none-any.whl size=19406 sha256=4ffff4c8114479f810449e4e67033622f892e89a6d0a0644b3ecae6660a3aa59
#   Stored in directory: c:\users\acer\appdata\local\pip\cache\wheels\88\65\21\97df31ae522f65c204de66377a95ca0f036a15cc28e880f5f6
# ...

# %%
import ezsheets

# %% [markdown]
# ![%E0%B8%A5%E0%B8%94%E0%B8%87%E0%B8%B2%E0%B8%99%E0%B8%94%E0%B9%89%E0%B8%A7%E0%B8%A2%20Python%202021.png](attachment:%E0%B8%A5%E0%B8%94%E0%B8%87%E0%B8%B2%E0%B8%99%E0%B8%94%E0%B9%89%E0%B8%A7%E0%B8%A2%20Python%202021.png)

# %% [markdown]
# ## เปิด Spread Sheet

# %%
spreadsheet = ezsheets.Spreadsheet('1hMbprUgMPACTT3vhl3oP9I6TPeL-EDVTtEf6KCtU7P0')

# %% [markdown]
# ## เปิด Sheet ใน Spread Sheet

# %%
spreadsheet['North'].title
# Out:
# 'North'

# %%
spreadsheet.sheets[0].title
# Out:
# 'North'

# %% [markdown]
# ## ดึงข้อมูลใน Cell จาก Sheet

# %%
north_sheet = spreadsheet['North']

# %%
north_sheet['A1'] = 'New Product'

# %% [markdown]
# ![%E0%B8%A5%E0%B8%94%E0%B8%87%E0%B8%B2%E0%B8%99%E0%B8%94%E0%B9%89%E0%B8%A7%E0%B8%A2%20Python%202021.png](attachment:%E0%B8%A5%E0%B8%94%E0%B8%87%E0%B8%B2%E0%B8%99%E0%B8%94%E0%B9%89%E0%B8%A7%E0%B8%A2%20Python%202021.png)

# %% [markdown]
# ## ดึงข้อมูลใน Cell จาก Sheet

# %%
north_sheet[1,1]
# Out:
# 'New Product'

# %% [markdown]
# ## การแปลงค่า Column

# %%
ezsheets.convertAddress('A2')
# Out:
# (1, 2)

# %%
ezsheets.convertAddress(1,2)
# Out:
# 'A2'

# %%
ezsheets.getColumnLetterOf(2)
# Out:
# 'B'

# %%
ezsheets.getColumnNumberOf('B')
# Out:
# 2

# %% [markdown]
# ![%E0%B8%A5%E0%B8%94%E0%B8%87%E0%B8%B2%E0%B8%99%E0%B8%94%E0%B9%89%E0%B8%A7%E0%B8%A2%20Python%202021.png](attachment:%E0%B8%A5%E0%B8%94%E0%B8%87%E0%B8%B2%E0%B8%99%E0%B8%94%E0%B9%89%E0%B8%A7%E0%B8%A2%20Python%202021.png)

# %% [markdown]
# ## การการแก้ไขจำนวน Row

# %%
north_sheet.rowCount = 12

# %% [markdown]
# ## การการแก้ไขจำนวน Column

# %%
north_sheet.columnCount = 4

# %% [markdown]
# ![%E0%B8%A5%E0%B8%94%E0%B8%87%E0%B8%B2%E0%B8%99%E0%B8%94%E0%B9%89%E0%B8%A7%E0%B8%A2%20Python%202021.png](attachment:%E0%B8%A5%E0%B8%94%E0%B8%87%E0%B8%B2%E0%B8%99%E0%B8%94%E0%B9%89%E0%B8%A7%E0%B8%A2%20Python%202021.png)

# %% [markdown]
# ## การดึง Column

# %%
north_sheet.getColumn(1)
# Out:
# ['Basil Leaf (Whole)',
#  'Celery Seed (Whole)',
#  'North Special',
#  'Catnip Leaf',
#  'Asafoetida Powder',
#  'Anise Seeds',
#  'Cardamom Seed (Ground)',
#  'Chamomile Flowers',
#  'Caraway Seed (Whole)',
#  'Cardamom Seed (Whole)',
#  'Bay Leaf (Whole)',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '']

# %%
north_sheet.getColumn('A')
# Out:
# ['Basil Leaf (Whole)',
#  'Celery Seed (Whole)',
#  'North Special',
#  'Catnip Leaf',
#  'Asafoetida Powder',
#  'Anise Seeds',
#  'Cardamom Seed (Ground)',
#  'Chamomile Flowers',
#  'Caraway Seed (Whole)',
#  'Cardamom Seed (Whole)',
#  'Bay Leaf (Whole)',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '']

# %% [markdown]
# ## การการแก้ไข Column

# %%
north_sheet.updateColumn(1, list(table['Product'].values))

# %% [markdown]
# ## การดึง Row

# %%
north_sheet.getRows(2)
# Out:
# [['Basil Leaf (Whole)', '$6,778', '$6,760', '$4,568'],
#  ['Celery Seed (Whole)', '$3,634', '$6,344', '$6,423'],
#  ['North Special', '$875', '$1,452', '$254'],
#  ['Catnip Leaf', '$854', '$364', '$474'],
#  ['Asafoetida Powder', '$654', '$634', '$326'],
#  ['Anise Seeds', '$534', '$423', '$521'],
#  ['Cardamom Seed (Ground)', '$422', '$642', '$642'],
#  ['Chamomile Flowers', '$356', '$634', '$632'],
#  ['Caraway Seed (Whole)', '$354', '$633', '$422'],
#  ['Cardamom Seed (Whole)', '$255', '$525', '$252'],
#  ['Bay Leaf (Whole)', '$233', '$532', '$525']]

# %% [markdown]
# ## การการแก้ไข Row

# %%
north_sheet.updateRow
